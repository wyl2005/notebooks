# %%
import os, sys

import numpy as np
import tensorflow as tf
from tensorflow import keras

tf.__version__
# Out:
# '1.14.0'

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

train_labels = train_labels[:1000]
test_labels = test_labels[:1000]

train_images = train_images[:1000].reshape(-1, 28*28) / 255.0
test_images = test_images[:1000].reshape(-1, 28*28) / 255.0

# %%
def create_model():
    model = tf.keras.models.Sequential([
        keras.layers.Dense(512,activation=tf.keras.activations.relu, input_shape=(784,)),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(10,activation=tf.keras.activations.softmax)
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['accuracy'])
    return model

model=create_model()
model.summary()
# Out:
# Model: "sequential_33"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_67 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path = "training_1/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                save_weights_only=True,
                                                verbose=1)
model = create_model()
model.fit(train_images,train_labels, epochs=10,
         validation_data=(test_images, test_labels),
         callbacks=[cp_callback])
# Out:
# Train on 1000 samples, validate on 1000 samples
# W0717 08:06:28.045492 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.046118 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.046662 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.047273 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.047944 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.048602 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.049236 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.049831 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.050392 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.050946 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.051550 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.052216 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.052867 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.053495 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.054384 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.055012 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.055599 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.056151 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.056769 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.057345 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.057950 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.058611 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.059286 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.059814 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.060488 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.061170 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.061867 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.062586 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.063661 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.064425 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.064960 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.065569 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.066171 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.066765 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.067505 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.068072 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.068813 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.069409 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.070103 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.070731 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.071327 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.072036 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.073027 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.073663 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.074293 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.074900 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.075602 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.076188 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.076759 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.077488 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.078075 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.078837 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.079519 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.080163 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.080876 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.081497 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.082547 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.094833 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.095427 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.096060 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.097369 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.097938 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.098630 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.099356 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.099962 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.100520 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.101083 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.101677 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.102249 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.102854 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.103838 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.104470 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.105087 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.105692 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.106289 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.106948 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.107525 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.108162 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.108825 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.109504 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.110087 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.110702 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.111316 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.111979 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.117337 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.117923 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.118508 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.119246 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.119815 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.120423 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.121067 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.121611 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.122273 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.122945 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.123576 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.124213 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.124845 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.125430 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.126306 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.126944 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.127627 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.128262 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.128990 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.129549 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.130200 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.130840 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.131395 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.131947 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.132570 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.133153 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.133711 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.134334 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.135225 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.135879 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.136442 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.136995 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.137595 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.138130 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.138780 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.139473 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.140078 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.140689 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.141272 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.141823 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.142546 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.143240 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.144118 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.144715 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.145339 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.145924 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.146522 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.147082 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.147632 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.148247 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.148819 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.149420 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.150073 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.150700 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.151368 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.151969 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.152886 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.153494 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.154061 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.154758 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.155473 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.156015 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.156579 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.157183 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.157729 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.158306 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.158926 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.159558 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.160149 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.160788 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# W0717 08:06:28.161652 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.iter
# W0717 08:06:28.162278 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_1
# W0717 08:06:28.162837 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.beta_2
# W0717 08:06:28.163479 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.decay
# W0717 08:06:28.164152 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer.learning_rate
# W0717 08:06:28.164735 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.165440 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.bias
# W0717 08:06:28.166096 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.166646 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.bias
# W0717 08:06:28.167214 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.kernel
# W0717 08:06:28.167846 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.bias
# W0717 08:06:28.168409 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.kernel
# W0717 08:06:28.169022 139695177439040 util.py:244] Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.bias
# W0717 08:06:28.169687 139695177439040 util.py:252] A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Epoch 1/10
#  544/1000 [===============>..............] - ETA: 0s - loss: 1.5285 - acc: 0.5257
# Epoch 00001: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 1s 569us/sample - loss: 1.1987 - acc: 0.6410 - val_loss: 0.6920 - val_acc: 0.7950
# Epoch 2/10
#  576/1000 [================>.............] - ETA: 0s - loss: 0.4675 - acc: 0.8576
# Epoch 00002: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 224us/sample - loss: 0.4298 - acc: 0.8780 - val_loss: 0.5352 - val_acc: 0.8320
# Epoch 3/10
#  640/1000 [==================>...........] - ETA: 0s - loss: 0.3050 - acc: 0.9266
# Epoch 00003: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 167us/sample - loss: 0.2915 - acc: 0.9210 - val_loss: 0.4809 - val_acc: 0.8460
# Epoch 4/10
#  576/1000 [================>.............] - ETA: 0s - loss: 0.2060 - acc: 0.9583
# Epoch 00004: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 167us/sample - loss: 0.2136 - acc: 0.9500 - val_loss: 0.4606 - val_acc: 0.8600
# Epoch 5/10
#  608/1000 [=================>............] - ETA: 0s - loss: 0.1622 - acc: 0.9589
# Epoch 00005: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 161us/sample - loss: 0.1698 - acc: 0.9610 - val_loss: 0.4477 - val_acc: 0.8610
# Epoch 6/10
#  608/1000 [=================>............] - ETA: 0s - loss: 0.1278 - acc: 0.9770
# Epoch 00006: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 172us/sample - loss: 0.1288 - acc: 0.9750 - val_loss: 0.4509 - val_acc: 0.8490
# Epoch 7/10
#  608/1000 [=================>............] - ETA: 0s - loss: 0.0786 - acc: 0.9901
# Epoch 00007: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 175us/sample - loss: 0.0916 - acc: 0.9830 - val_loss: 0.4187 - val_acc: 0.8670
# Epoch 8/10
#  512/1000 [==============>...............] - ETA: 0s - loss: 0.0633 - acc: 0.9980
# Epoch 00008: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 177us/sample - loss: 0.0717 - acc: 0.9910 - val_loss: 0.4210 - val_acc: 0.8630
# Epoch 9/10
#  544/1000 [===============>..............] - ETA: 0s - loss: 0.0503 - acc: 1.0000
# Epoch 00009: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 164us/sample - loss: 0.0514 - acc: 0.9990 - val_loss: 0.4174 - val_acc: 0.8750
# Epoch 10/10
#  608/1000 [=================>............] - ETA: 0s - loss: 0.0355 - acc: 1.0000
# Epoch 00010: saving model to training_1/cp.ckpt
# 1000/1000 [==============================] - 0s 170us/sample - loss: 0.0389 - acc: 0.9990 - val_loss: 0.4081 - val_acc: 0.8670

# %%
# !ls {checkpoint_dir}
# Out:
# checkpoint		     cp.ckpt.data-00001-of-00002
# cp.ckpt.data-00000-of-00002  cp.ckpt.index

# %%
model = create_model()

loss,acc=model.evaluate(test_images, test_labels)
print("Untrained model, accuracy:{:5.2f}%".format(100*acc))
print("acc:%2.5f%%" % (acc*100))
acc*100
#help(acc)
# Out:
# 1000/1000 [==============================] - 0s 105us/sample - loss: 2.3829 - acc: 0.1460
# Untrained model, accuracy:14.60%
# acc:14.60000%
# 14.599999785423279

# %%
model.load_weights(checkpoint_path)
loss,acc = model.evaluate(test_images, test_labels)
print("Restored model, accuracy:{:5.2f}%".format(100*acc))

print("{:08.3f}".format(32233.1415926))
print("{:08d}".format(322))
# Out:
# 1000/1000 [==============================] - 0s 45us/sample - loss: 0.4081 - acc: 0.8670
# Restored model, accuracy:86.70%
# 32233.142
# 00000322

# %%
checkpoint_path = "training_2/cp-{epoch:04d}.ckpt"
checkpoint_dir=os.path.dirname(checkpoint_path)

cp_callback=tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, verbose=1, save_weight_only=True,
    #save weights every 5-epochs.
    save_freq=5)

model=create_model()
model.save_weights(checkpoint_path.format(epoch=0))
model.fit(train_images,train_labels,
         epochs=50,callbacks=[cp_callback],
         validation_data=(test_images,test_labels),
         verbose=0)
# Out:
# Epoch 00001: saving model to training_2/cp-0001.ckpt
# W0717 08:10:03.556261 139695177439040 callbacks.py:257] Method (on_train_batch_end) is slow compared to the batch update (0.339777). Check your callbacks.
# W0717 08:10:03.648552 139695177439040 callbacks.py:257] Method (on_train_batch_end) is slow compared to the batch update (0.213259). Check your callbacks.
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00001: saving model to training_2/cp-0001.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00002: saving model to training_2/cp-0002.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00003: saving model to training_2/cp-0003.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00004: saving model to training_2/cp-0004.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00005: saving model to training_2/cp-0005.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00006: saving model to training_2/cp-0006.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00007: saving model to training_2/cp-0007.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00008: saving model to training_2/cp-0008.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00009: saving model to training_2/cp-0009.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00010: saving model to training_2/cp-0010.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00011: saving model to training_2/cp-0011.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00012: saving model to training_2/cp-0012.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00013: saving model to training_2/cp-0013.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00014: saving model to training_2/cp-0014.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00015: saving model to training_2/cp-0015.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00016: saving model to training_2/cp-0016.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00017: saving model to training_2/cp-0017.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00018: saving model to training_2/cp-0018.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00019: saving model to training_2/cp-0019.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00020: saving model to training_2/cp-0020.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00021: saving model to training_2/cp-0021.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00022: saving model to training_2/cp-0022.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00023: saving model to training_2/cp-0023.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00024: saving model to training_2/cp-0024.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00025: saving model to training_2/cp-0025.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00026: saving model to training_2/cp-0026.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00027: saving model to training_2/cp-0027.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# Epoch 00028: saving model to training_2/cp-0028.ckpt
#
# ...
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00041: saving model to training_2/cp-0041.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00042: saving model to training_2/cp-0042.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00043: saving model to training_2/cp-0043.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00044: saving model to training_2/cp-0044.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00045: saving model to training_2/cp-0045.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00046: saving model to training_2/cp-0046.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00047: saving model to training_2/cp-0047.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00048: saving model to training_2/cp-0048.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00049: saving model to training_2/cp-0049.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt
#
# Epoch 00050: saving model to training_2/cp-0050.ckpt

# %%
! ls {checkpoint_dir}
# Out:
# checkpoint			  cp-0011.ckpt	cp-0025.ckpt  cp-0039.ckpt
# cp-0000.ckpt.data-00000-of-00002  cp-0012.ckpt	cp-0026.ckpt  cp-0040.ckpt
# cp-0000.ckpt.data-00001-of-00002  cp-0013.ckpt	cp-0027.ckpt  cp-0041.ckpt
# cp-0000.ckpt.index		  cp-0014.ckpt	cp-0028.ckpt  cp-0042.ckpt
# cp-0001.ckpt			  cp-0015.ckpt	cp-0029.ckpt  cp-0043.ckpt
# cp-0002.ckpt			  cp-0016.ckpt	cp-0030.ckpt  cp-0044.ckpt
# cp-0003.ckpt			  cp-0017.ckpt	cp-0031.ckpt  cp-0045.ckpt
# cp-0004.ckpt			  cp-0018.ckpt	cp-0032.ckpt  cp-0046.ckpt
# cp-0005.ckpt			  cp-0019.ckpt	cp-0033.ckpt  cp-0047.ckpt
# cp-0006.ckpt			  cp-0020.ckpt	cp-0034.ckpt  cp-0048.ckpt
# cp-0007.ckpt			  cp-0021.ckpt	cp-0035.ckpt  cp-0049.ckpt
# cp-0008.ckpt			  cp-0022.ckpt	cp-0036.ckpt  cp-0050.ckpt
# cp-0009.ckpt			  cp-0023.ckpt	cp-0037.ckpt
# cp-0010.ckpt			  cp-0024.ckpt	cp-0038.ckpt

# %%
latest = tf.train.latest_checkpoint(checkpoint_dir)
latest
# Out:
# 'training_2/cp-0000.ckpt'

# %%
model=create_model()
model.load_weights(latest)
loss, acc = model.evaluate(test_images, test_labels)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 122us/sample - loss: 2.3168 - acc: 0.1160
# Restored model, accuracy: 11.60%

# %%
# save the weights

model.save_weights('./checkpoint/my_checkpoint')

#restore the weights
model=create_model()
model.load_weights('./checkpoint/my_checkpoint')

loss,acc = model.evaluate(test_images, test_labels)
print("restored model, accuracy:{:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 123us/sample - loss: 2.3168 - acc: 0.1160
# restored model, accuracy:11.60%

# %%
model = create_model()
model.fit(train_images, train_labels, epochs=5)

loss, acc = new_model.evaluate(test_images,test_labels)
print("model,accuracy: {:5.2f}%".format(100*acc))

model.save('my_model.h5')
# Out:
# Epoch 1/5
# 1000/1000 [==============================] - 0s 217us/sample - loss: 1.1515 - acc: 0.6620
# Epoch 2/5
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.4136 - acc: 0.8850
# Epoch 3/5
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.2748 - acc: 0.9380
# Epoch 4/5
# 1000/1000 [==============================] - 0s 102us/sample - loss: 0.2064 - acc: 0.9550
# Epoch 5/5
# 1000/1000 [==============================] - 0s 106us/sample - loss: 0.1507 - acc: 0.9700
# 1000/1000 [==============================] - 0s 53us/sample - loss: 0.4528 - acc: 0.8530
# model,accuracy: 85.30%

# %%
new_model=keras.models.load_model('my_model.h5')
new_model.summary()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_82 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
loss, acc = new_model.evaluate(test_images,test_labels)
print("Restored model,accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 142us/sample - loss: 0.4528 - acc: 0.8530
# Restored model,accuracy: 85.30%

# %%
model=create_model()
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1000/1000 [==============================] - 0s 230us/sample - loss: 1.1259 - acc: 0.6670
# Epoch 2/5
# 1000/1000 [==============================] - 0s 103us/sample - loss: 0.4235 - acc: 0.8770
# Epoch 3/5
# 1000/1000 [==============================] - 0s 99us/sample - loss: 0.2833 - acc: 0.9230
# Epoch 4/5
# 1000/1000 [==============================] - 0s 101us/sample - loss: 0.2090 - acc: 0.9460
# Epoch 5/5
# 1000/1000 [==============================] - 0s 98us/sample - loss: 0.1483 - acc: 0.9660

# %%
import time

str(int(time.time()))
saved_model_path = "./saved_models/"+str(int(time.time()))
tf.contrib.saved_model.save_keras_model(model, saved_model_path)
# Out:
# W0717 09:51:38.226956 139695177439040 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:253: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0717 09:51:38.228679 139695177439040 export_utils.py:182] Export includes no default signature!
# W0717 09:51:38.468261 139695177439040 export_utils.py:182] Export includes no default signature!

# %%
new_model=tf.contrib.saved_model.load_keras_model(saved_model_path)
new_model.summary()
# Out:
# Model: "sequential_44"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_88 (Dense)             (None, 512)               401920
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
new_model.compile(optimizer=tf.keras.optimizers.Adam(),
                 loss=tf.keras.losses.sparse_categorical_crossentropy,
                 metrics=['accuracy'])
loss,acc=new_model.evaluate(test_images, test_labels)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 1000/1000 [==============================] - 0s 146us/sample - loss: 0.4564 - acc: 0.8620
# Restored model, accuracy: 86.20%
