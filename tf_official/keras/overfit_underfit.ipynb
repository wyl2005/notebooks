# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import sys

print(tf.__version__)
# Out:
# 1.14.0

# %%
NUM_WORDS = 10000

print(NUM_WORDS)

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)
print("222")
# Out:
# 10000
# 222

# %% [markdown]
# import sys
# a=np.zeros((25000, 10000), dtype=np.int8)
#
# a.shape
# help(a)
# a.data
# print("size: 0x%x" % sys.getsizeof(a))
# print("size: %d " % sys.getsizeof(a))

# %%
NUM_WORDS = 10000



print(NUM_WORDS)

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)
print("111")
def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension), dtype=np.int8)
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


print("2")
train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
print("train_data size %d" % sys.getsizeof(train_data))
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)
print("test_data size %d" % sys.getsizeof(test_data))
# Out:
# 10000
# 111
# 2
# train_data size 250000112
# test_data size 250000112

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works.
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_34 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                     train_labels,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(test_data,test_labels),
                                     verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.4850 - acc: 0.7985 - binary_crossentropy: 0.4850 - val_loss: 0.3402 - val_acc: 0.8777 - val_binary_crossentropy: 0.3402
# Epoch 2/20
# 25000/25000 - 1s - loss: 0.2524 - acc: 0.9118 - binary_crossentropy: 0.2524 - val_loss: 0.2861 - val_acc: 0.8876 - val_binary_crossentropy: 0.2861
# Epoch 3/20
# 25000/25000 - 1s - loss: 0.1842 - acc: 0.9352 - binary_crossentropy: 0.1842 - val_loss: 0.2905 - val_acc: 0.8832 - val_binary_crossentropy: 0.2905
# Epoch 4/20
# 25000/25000 - 1s - loss: 0.1489 - acc: 0.9494 - binary_crossentropy: 0.1489 - val_loss: 0.3211 - val_acc: 0.8737 - val_binary_crossentropy: 0.3211
# Epoch 5/20
# 25000/25000 - 1s - loss: 0.1226 - acc: 0.9591 - binary_crossentropy: 0.1226 - val_loss: 0.3338 - val_acc: 0.8744 - val_binary_crossentropy: 0.3338
# Epoch 6/20
# 25000/25000 - 1s - loss: 0.1016 - acc: 0.9683 - binary_crossentropy: 0.1016 - val_loss: 0.3632 - val_acc: 0.8709 - val_binary_crossentropy: 0.3632
# Epoch 7/20
# 25000/25000 - 1s - loss: 0.0846 - acc: 0.9740 - binary_crossentropy: 0.0846 - val_loss: 0.3960 - val_acc: 0.8682 - val_binary_crossentropy: 0.3960
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.0718 - acc: 0.9799 - binary_crossentropy: 0.0718 - val_loss: 0.4325 - val_acc: 0.8642 - val_binary_crossentropy: 0.4325
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.0577 - acc: 0.9855 - binary_crossentropy: 0.0577 - val_loss: 0.4695 - val_acc: 0.8622 - val_binary_crossentropy: 0.4695
# Epoch 10/20
# 25000/25000 - 1s - loss: 0.0480 - acc: 0.9891 - binary_crossentropy: 0.0480 - val_loss: 0.5106 - val_acc: 0.8595 - val_binary_crossentropy: 0.5106
# Epoch 11/20
# 25000/25000 - 1s - loss: 0.0373 - acc: 0.9930 - binary_crossentropy: 0.0373 - val_loss: 0.5502 - val_acc: 0.8572 - val_binary_crossentropy: 0.5502
# Epoch 12/20
# 25000/25000 - 1s - loss: 0.0290 - acc: 0.9954 - binary_crossentropy: 0.0290 - val_loss: 0.5895 - val_acc: 0.8568 - val_binary_crossentropy: 0.5895
# Epoch 13/20
# 25000/25000 - 1s - loss: 0.0229 - acc: 0.9973 - binary_crossentropy: 0.0229 - val_loss: 0.6312 - val_acc: 0.8543 - val_binary_crossentropy: 0.6312
# Epoch 14/20
# 25000/25000 - 1s - loss: 0.0174 - acc: 0.9984 - binary_crossentropy: 0.0174 - val_loss: 0.6749 - val_acc: 0.8532 - val_binary_crossentropy: 0.6749
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0135 - acc: 0.9990 - binary_crossentropy: 0.0135 - val_loss: 0.6987 - val_acc: 0.8524 - val_binary_crossentropy: 0.6987
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0107 - acc: 0.9994 - binary_crossentropy: 0.0107 - val_loss: 0.7427 - val_acc: 0.8514 - val_binary_crossentropy: 0.7427
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0085 - acc: 0.9997 - binary_crossentropy: 0.0085 - val_loss: 0.7714 - val_acc: 0.8518 - val_binary_crossentropy: 0.7714
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0065 - acc: 0.9998 - binary_crossentropy: 0.0065 - val_loss: 0.8107 - val_acc: 0.8512 - val_binary_crossentropy: 0.8107
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0052 - acc: 0.9998 - binary_crossentropy: 0.0052 - val_loss: 0.8460 - val_acc: 0.8515 - val_binary_crossentropy: 0.8460
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0042 - acc: 0.9999 - binary_crossentropy: 0.0042 - val_loss: 0.8764 - val_acc: 0.8505 - val_binary_crossentropy: 0.8764

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS, )),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 4)                 40004
# _________________________________________________________________
# dense_37 (Dense)             (None, 4)                 20
# _________________________________________________________________
# dense_38 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                     train_labels,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(test_data,test_labels),
                                     verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 3s - loss: 0.6421 - acc: 0.6044 - binary_crossentropy: 0.6421 - val_loss: 0.5839 - val_acc: 0.7132 - val_binary_crossentropy: 0.5839
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.5322 - acc: 0.7964 - binary_crossentropy: 0.5322 - val_loss: 0.5191 - val_acc: 0.8110 - val_binary_crossentropy: 0.5191
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.4723 - acc: 0.8654 - binary_crossentropy: 0.4723 - val_loss: 0.4832 - val_acc: 0.8583 - val_binary_crossentropy: 0.4832
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.4326 - acc: 0.8978 - binary_crossentropy: 0.4326 - val_loss: 0.4614 - val_acc: 0.8676 - val_binary_crossentropy: 0.4614
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.4016 - acc: 0.9162 - binary_crossentropy: 0.4016 - val_loss: 0.4492 - val_acc: 0.8652 - val_binary_crossentropy: 0.4492
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.3760 - acc: 0.9303 - binary_crossentropy: 0.3760 - val_loss: 0.4355 - val_acc: 0.8788 - val_binary_crossentropy: 0.4355
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.3542 - acc: 0.9408 - binary_crossentropy: 0.3542 - val_loss: 0.4310 - val_acc: 0.8738 - val_binary_crossentropy: 0.4310
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.3348 - acc: 0.9490 - binary_crossentropy: 0.3348 - val_loss: 0.4286 - val_acc: 0.8731 - val_binary_crossentropy: 0.4286
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.3168 - acc: 0.9561 - binary_crossentropy: 0.3168 - val_loss: 0.4227 - val_acc: 0.8757 - val_binary_crossentropy: 0.4227
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.3010 - acc: 0.9606 - binary_crossentropy: 0.3010 - val_loss: 0.4184 - val_acc: 0.8762 - val_binary_crossentropy: 0.4184
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.2862 - acc: 0.9652 - binary_crossentropy: 0.2862 - val_loss: 0.4213 - val_acc: 0.8733 - val_binary_crossentropy: 0.4213
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.2727 - acc: 0.9694 - binary_crossentropy: 0.2727 - val_loss: 0.4192 - val_acc: 0.8738 - val_binary_crossentropy: 0.4192
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.2605 - acc: 0.9726 - binary_crossentropy: 0.2605 - val_loss: 0.4217 - val_acc: 0.8718 - val_binary_crossentropy: 0.4217
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.2484 - acc: 0.9745 - binary_crossentropy: 0.2484 - val_loss: 0.4235 - val_acc: 0.8714 - val_binary_crossentropy: 0.4235
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.2376 - acc: 0.9776 - binary_crossentropy: 0.2376 - val_loss: 0.4279 - val_acc: 0.8708 - val_binary_crossentropy: 0.4279
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.2271 - acc: 0.9794 - binary_crossentropy: 0.2271 - val_loss: 0.4281 - val_acc: 0.8704 - val_binary_crossentropy: 0.4281
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.2179 - acc: 0.9818 - binary_crossentropy: 0.2179 - val_loss: 0.4345 - val_acc: 0.8692 - val_binary_crossentropy: 0.4345
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.2089 - acc: 0.9833 - binary_crossentropy: 0.2089 - val_loss: 0.4440 - val_acc: 0.8682 - val_binary_crossentropy: 0.4440
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.2007 - acc: 0.9846 - binary_crossentropy: 0.2007 - val_loss: 0.4459 - val_acc: 0.8669 - val_binary_crossentropy: 0.4459
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.1926 - acc: 0.9857 - binary_crossentropy: 0.1926 - val_loss: 0.4505 - val_acc: 0.8666 - val_binary_crossentropy: 0.4505

# %%
bigger_model = keras.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS, )),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

bigger_model.summary()
print("size: %s" % sys.getsizeof(bigger_model))
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_39 (Dense)             (None, 512)               5120512
# _________________________________________________________________
# dense_40 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________
# size: 56

# %%
bigger_history = bigger_model.fit(train_data,
                                     train_labels,
                                     epochs=20,
                                     batch_size=512,
                                     validation_data=(test_data,test_labels),
                                     verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 16s - loss: 0.3502 - acc: 0.8482 - binary_crossentropy: 0.3502 - val_loss: 0.2813 - val_acc: 0.8849 - val_binary_crossentropy: 0.2813
# Epoch 2/20
# 25000/25000 - 11s - loss: 0.1327 - acc: 0.9532 - binary_crossentropy: 0.1327 - val_loss: 0.3215 - val_acc: 0.8766 - val_binary_crossentropy: 0.3215
# Epoch 3/20
# 25000/25000 - 10s - loss: 0.0385 - acc: 0.9894 - binary_crossentropy: 0.0385 - val_loss: 0.4460 - val_acc: 0.8683 - val_binary_crossentropy: 0.4460
# Epoch 4/20
# 25000/25000 - 10s - loss: 0.0057 - acc: 0.9992 - binary_crossentropy: 0.0057 - val_loss: 0.6052 - val_acc: 0.8703 - val_binary_crossentropy: 0.6052
# Epoch 5/20
# 25000/25000 - 10s - loss: 6.1161e-04 - acc: 1.0000 - binary_crossentropy: 6.1161e-04 - val_loss: 0.6761 - val_acc: 0.8748 - val_binary_crossentropy: 0.6761
# Epoch 6/20
# 25000/25000 - 10s - loss: 2.0531e-04 - acc: 1.0000 - binary_crossentropy: 2.0531e-04 - val_loss: 0.7187 - val_acc: 0.8742 - val_binary_crossentropy: 0.7187
# Epoch 7/20
# 25000/25000 - 10s - loss: 1.2975e-04 - acc: 1.0000 - binary_crossentropy: 1.2975e-04 - val_loss: 0.7479 - val_acc: 0.8744 - val_binary_crossentropy: 0.7479
# Epoch 8/20
# 25000/25000 - 10s - loss: 9.4387e-05 - acc: 1.0000 - binary_crossentropy: 9.4387e-05 - val_loss: 0.7707 - val_acc: 0.8744 - val_binary_crossentropy: 0.7707
# Epoch 9/20
# 25000/25000 - 10s - loss: 7.2285e-05 - acc: 1.0000 - binary_crossentropy: 7.2285e-05 - val_loss: 0.7894 - val_acc: 0.8748 - val_binary_crossentropy: 0.7894
# Epoch 10/20
# 25000/25000 - 10s - loss: 5.7316e-05 - acc: 1.0000 - binary_crossentropy: 5.7316e-05 - val_loss: 0.8061 - val_acc: 0.8748 - val_binary_crossentropy: 0.8061
# Epoch 11/20
# 25000/25000 - 10s - loss: 4.6584e-05 - acc: 1.0000 - binary_crossentropy: 4.6584e-05 - val_loss: 0.8216 - val_acc: 0.8746 - val_binary_crossentropy: 0.8216
# Epoch 12/20
# 25000/25000 - 10s - loss: 3.8548e-05 - acc: 1.0000 - binary_crossentropy: 3.8548e-05 - val_loss: 0.8354 - val_acc: 0.8746 - val_binary_crossentropy: 0.8354
# Epoch 13/20
# 25000/25000 - 10s - loss: 3.2358e-05 - acc: 1.0000 - binary_crossentropy: 3.2358e-05 - val_loss: 0.8479 - val_acc: 0.8748 - val_binary_crossentropy: 0.8479
# Epoch 14/20
# 25000/25000 - 10s - loss: 2.7528e-05 - acc: 1.0000 - binary_crossentropy: 2.7528e-05 - val_loss: 0.8602 - val_acc: 0.8745 - val_binary_crossentropy: 0.8602
# Epoch 15/20
# 25000/25000 - 12s - loss: 2.3603e-05 - acc: 1.0000 - binary_crossentropy: 2.3603e-05 - val_loss: 0.8710 - val_acc: 0.8747 - val_binary_crossentropy: 0.8710
# Epoch 16/20
# 25000/25000 - 10s - loss: 2.0461e-05 - acc: 1.0000 - binary_crossentropy: 2.0461e-05 - val_loss: 0.8818 - val_acc: 0.8745 - val_binary_crossentropy: 0.8818
# Epoch 17/20
# 25000/25000 - 10s - loss: 1.7856e-05 - acc: 1.0000 - binary_crossentropy: 1.7856e-05 - val_loss: 0.8915 - val_acc: 0.8747 - val_binary_crossentropy: 0.8915
# Epoch 18/20
# 25000/25000 - 10s - loss: 1.5711e-05 - acc: 1.0000 - binary_crossentropy: 1.5711e-05 - val_loss: 0.9011 - val_acc: 0.8748 - val_binary_crossentropy: 0.9011
# Epoch 19/20
# 25000/25000 - 11s - loss: 1.3898e-05 - acc: 1.0000 - binary_crossentropy: 1.3898e-05 - val_loss: 0.9102 - val_acc: 0.8746 - val_binary_crossentropy: 0.9102
# Epoch 20/20
# 25000/25000 - 11s - loss: 1.2350e-05 - acc: 1.0000 - binary_crossentropy: 1.2350e-05 - val_loss: 0.9187 - val_acc: 0.8747 - val_binary_crossentropy: 0.9187

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16, 10))
    
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                      '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
                label=name.title()+' Train')
        
    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_', ' ').title())
    plt.legend()
    
    plt.xlim([0, max(history.epoch)])
    
plot_history([('baseline',baseline_history),
            ('smaller',smaller_history),
            ('bigger',bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                      activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                      activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                               epochs=20,
                               batch_size=512,
                               validation_data=(test_data, test_labels),
                               verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.5275 - acc: 0.8022 - binary_crossentropy: 0.4876 - val_loss: 0.3821 - val_acc: 0.8766 - val_binary_crossentropy: 0.3403
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.3040 - acc: 0.9089 - binary_crossentropy: 0.2578 - val_loss: 0.3331 - val_acc: 0.8889 - val_binary_crossentropy: 0.2838
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.2526 - acc: 0.9291 - binary_crossentropy: 0.2011 - val_loss: 0.3374 - val_acc: 0.8866 - val_binary_crossentropy: 0.2842
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2284 - acc: 0.9412 - binary_crossentropy: 0.1734 - val_loss: 0.3501 - val_acc: 0.8823 - val_binary_crossentropy: 0.2941
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2157 - acc: 0.9434 - binary_crossentropy: 0.1584 - val_loss: 0.3663 - val_acc: 0.8783 - val_binary_crossentropy: 0.3080
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2037 - acc: 0.9507 - binary_crossentropy: 0.1446 - val_loss: 0.3787 - val_acc: 0.8755 - val_binary_crossentropy: 0.3191
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.1944 - acc: 0.9544 - binary_crossentropy: 0.1342 - val_loss: 0.3918 - val_acc: 0.8731 - val_binary_crossentropy: 0.3312
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1871 - acc: 0.9571 - binary_crossentropy: 0.1259 - val_loss: 0.4071 - val_acc: 0.8700 - val_binary_crossentropy: 0.3455
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1848 - acc: 0.9580 - binary_crossentropy: 0.1224 - val_loss: 0.4300 - val_acc: 0.8676 - val_binary_crossentropy: 0.3671
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1793 - acc: 0.9596 - binary_crossentropy: 0.1160 - val_loss: 0.4349 - val_acc: 0.8661 - val_binary_crossentropy: 0.3714
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1740 - acc: 0.9636 - binary_crossentropy: 0.1100 - val_loss: 0.4518 - val_acc: 0.8629 - val_binary_crossentropy: 0.3876
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1679 - acc: 0.9665 - binary_crossentropy: 0.1034 - val_loss: 0.4592 - val_acc: 0.8644 - val_binary_crossentropy: 0.3947
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1667 - acc: 0.9657 - binary_crossentropy: 0.1019 - val_loss: 0.4840 - val_acc: 0.8588 - val_binary_crossentropy: 0.4188
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.1641 - acc: 0.9669 - binary_crossentropy: 0.0986 - val_loss: 0.4920 - val_acc: 0.8592 - val_binary_crossentropy: 0.4261
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.1622 - acc: 0.9658 - binary_crossentropy: 0.0958 - val_loss: 0.4992 - val_acc: 0.8595 - val_binary_crossentropy: 0.4325
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.1609 - acc: 0.9675 - binary_crossentropy: 0.0937 - val_loss: 0.5191 - val_acc: 0.8572 - val_binary_crossentropy: 0.4512
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.1556 - acc: 0.9696 - binary_crossentropy: 0.0876 - val_loss: 0.5298 - val_acc: 0.8564 - val_binary_crossentropy: 0.4620
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.1543 - acc: 0.9696 - binary_crossentropy: 0.0863 - val_loss: 0.5493 - val_acc: 0.8543 - val_binary_crossentropy: 0.4807
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.1515 - acc: 0.9709 - binary_crossentropy: 0.0829 - val_loss: 0.5558 - val_acc: 0.8544 - val_binary_crossentropy: 0.4872
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.1499 - acc: 0.9728 - binary_crossentropy: 0.0810 - val_loss: 0.5629 - val_acc: 0.8543 - val_binary_crossentropy: 0.4937

# %%
plot_history([('baseline', baseline_history),
             ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS, )),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])
dpt_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

                                 epochs=20,
                                 batch_size=512,
                                 validation_data=(test_data, test_labels),
                                 verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.6312 - acc: 0.6455 - binary_crossentropy: 0.6312 - val_loss: 0.5357 - val_acc: 0.8505 - val_binary_crossentropy: 0.5357
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4876 - acc: 0.7988 - binary_crossentropy: 0.4876 - val_loss: 0.3977 - val_acc: 0.8796 - val_binary_crossentropy: 0.3977
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.3918 - acc: 0.8517 - binary_crossentropy: 0.3918 - val_loss: 0.3186 - val_acc: 0.8833 - val_binary_crossentropy: 0.3186
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.3218 - acc: 0.8864 - binary_crossentropy: 0.3218 - val_loss: 0.2868 - val_acc: 0.8896 - val_binary_crossentropy: 0.2868
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2763 - acc: 0.9080 - binary_crossentropy: 0.2763 - val_loss: 0.2789 - val_acc: 0.8878 - val_binary_crossentropy: 0.2789
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2379 - acc: 0.9230 - binary_crossentropy: 0.2379 - val_loss: 0.2837 - val_acc: 0.8867 - val_binary_crossentropy: 0.2837
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.2124 - acc: 0.9326 - binary_crossentropy: 0.2124 - val_loss: 0.2954 - val_acc: 0.8868 - val_binary_crossentropy: 0.2954
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1931 - acc: 0.9386 - binary_crossentropy: 0.1931 - val_loss: 0.3043 - val_acc: 0.8857 - val_binary_crossentropy: 0.3043
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1742 - acc: 0.9459 - binary_crossentropy: 0.1742 - val_loss: 0.3423 - val_acc: 0.8831 - val_binary_crossentropy: 0.3423
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1567 - acc: 0.9503 - binary_crossentropy: 0.1567 - val_loss: 0.3405 - val_acc: 0.8825 - val_binary_crossentropy: 0.3405
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1398 - acc: 0.9553 - binary_crossentropy: 0.1398 - val_loss: 0.3628 - val_acc: 0.8824 - val_binary_crossentropy: 0.3628
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1313 - acc: 0.9591 - binary_crossentropy: 0.1313 - val_loss: 0.3718 - val_acc: 0.8804 - val_binary_crossentropy: 0.3718
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1222 - acc: 0.9614 - binary_crossentropy: 0.1222 - val_loss: 0.4124 - val_acc: 0.8802 - val_binary_crossentropy: 0.4124
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.1152 - acc: 0.9626 - binary_crossentropy: 0.1152 - val_loss: 0.4335 - val_acc: 0.8786 - val_binary_crossentropy: 0.4335
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.1043 - acc: 0.9662 - binary_crossentropy: 0.1043 - val_loss: 0.4570 - val_acc: 0.8773 - val_binary_crossentropy: 0.4570
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.1029 - acc: 0.9660 - binary_crossentropy: 0.1029 - val_loss: 0.4538 - val_acc: 0.8767 - val_binary_crossentropy: 0.4538
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0983 - acc: 0.9674 - binary_crossentropy: 0.0983 - val_loss: 0.4912 - val_acc: 0.8755 - val_binary_crossentropy: 0.4912
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0934 - acc: 0.9687 - binary_crossentropy: 0.0934 - val_loss: 0.4860 - val_acc: 0.8756 - val_binary_crossentropy: 0.4860
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0875 - acc: 0.9706 - binary_crossentropy: 0.0875 - val_loss: 0.5409 - val_acc: 0.8758 - val_binary_crossentropy: 0.5409
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0842 - acc: 0.9722 - binary_crossentropy: 0.0842 - val_loss: 0.5254 - val_acc: 0.8750 - val_binary_crossentropy: 0.5254

# %%
plot_history([('baseline', baseline_history),
             ('droptout', dpt_model_history)])
